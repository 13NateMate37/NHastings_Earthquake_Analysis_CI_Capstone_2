# %% [markdown]
# # **Earthquake Analysis**
# ## *EDA Notebook*

# %% [markdown]
# ## Objectives
#
# * Investigate the characteristics of our target values to further inform the exploratory process
#
# * Visualise how our target features interact and translate the insights of the behaviour
#
#
# ## Inputs
#
# * The cleaned 'earthquake_1995-2023_cleaned.csv'
#
# * Libraries containing the tools needed. Pandas, numpy, matplotlib.
#
# ## Outputs
#
# * Analysis & Visualisations of the target variables
#
# * Information to inform the testing phase.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Earthquake_Analysis\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Earthquake_Analysis'

# %% [markdown]
# # Import block

# %% [markdown]
# These are the libraries required to process and inspect the data.

# %%
# Librairies needed to perform analysis
# Modules from sklearn and scipy will 
# be imported as needed

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# And load the .csv to a dataframe

# %%
# .csv to dataframe
df_clean = pd.read_csv("Dataset/Cleaned/earthquake_1995-2023_cleaned.csv")

# View the dataframe
df_clean.head(10)
# Out:
#                                                title  magnitude  \
# 0                   M 6.5 - 42 km W of Sola, Vanuatu        6.5
# 1           M 6.5 - 43 km S of Intipucá, El Salvador        6.5
# 2           M 6.6 - 25 km ESE of Loncopué, Argentina        6.6
# 3              M 7.2 - 98 km S of Sand Point, Alaska        7.2
# 4                           M 7.3 - Alaska Peninsula        7.3
# 5  M 6.6 - 277 km NNE of Codrington, Antigua and ...        6.6
# 6                                      M 6.9 - Tonga        6.9
# 7                  M 7.2 - south of the Fiji Islands        7.2
# 8              M 6.6 - Panama-Colombia border region        6.6
# 9           M 7.1 - southeast of the Loyalty Islands        7.1
#
#              date_time  cdi  mmi       alert  tsunami  sig net  nst  ...  \
# 0  2023-08-16 12:47:00    7    4       green        0  657  us  114  ...
# 1  2023-07-19 00:22:00    8    6      yellow        0  775  us   92  ...
# 2  2023-07-17 03:05:00    7    5       green        0  899  us   70  ...
# 3  2023-07-16 06:48:00    6    6       green        1  860  us  173  ...
# 4  2023-07-16 06:48:00    0    5  unassigned        1  820  at   79  ...
# 5  2023-07-10 20:28:00    5    4       green        1  802  us   95  ...
# 6  2023-07-02 10:27:00    4    4       green        1  741  us  136  ...
# 7  2023-06-15 18:06:00    8    6       green        1  804  us   85  ...
# 8  2023-05-25 03:05:00    6    6       green        1  733  us   50  ...
# 9  2023-05-20 01:51:00    3    4       green        1  777  us   98  ...
#
#        continent    country mag_depth_interaction     depth_cat  is_off_shore  \
# 0      off_shore    Vanuatu               1254.21  Intermediate         False
# 1      off_shore  off_shore                453.23       shallow          True
# 2  South America  Argentina               1131.05  Intermediate         False
# 3      off_shore  off_shore                234.51       shallow          True
# 4      off_shore  off_shore                153.30       shallow          True
# 5      off_shore  off_shore                 66.00       shallow          True
# 6      off_shore  off_shore               1580.10  Intermediate          True
# 7      off_shore  off_shore               1205.31  Intermediate          True
# 8      off_shore   Colombia                 66.00       shallow         False
# 9      off_shore  off_shore                255.47       shallow          True
#
#    high high_severity  year month  hour
# 0     0             0  2023     8    12
# 1     0             0  2023     7     0
# 2     1             1  2023     7     3
# 3     0             0  2023     7     6
# 4     0             0  2023     7     6
# 5     0             0  2023     7    20
# 6     0             0  2023     7    10
# 7     0             0  2023     6    18
# 8     0             0  2023     5     3
# 9     0             0  2023     5     1
#
# [10 rows x 27 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Section 1 - Exploration of the Continuous

# %% [markdown]
# We're going to to take a closer look at the distributions of our data.
#
# First we'll inspect the continuous features, magnitude and depth.

# %%
stat_summ = df_clean[["magnitude", "depth"]].agg(
    ["mean", "median", "min", "max", "std"]
)
print("Summary:")
print(stat_summ.round(2))
# Out:
# Summary:
#         magnitude   depth
# mean         6.94   74.61
# median       6.80   29.00
# min          6.50    2.70
# max          9.10  670.81
# std          0.44  130.81

# %%
# Storing columns into a variable 
continuous_columns = ["magnitude", "depth"]

# Visualise them
# Method and format taken from Code Institues 
# 'Descriptive Statistics Topic 3: Variability' lesson notebook
for column in continuous_columns:
  fig, axes = plt.subplots(figsize=(8,5))
  plt.title(f"{column} distribution")
  sns.histplot(
    data=df_clean,
    x=column,
    kde=True
  )

  plt.axvline(df_clean[column].mean(), color='r', linestyle='dashed', linewidth=2)
  plt.text(x=df_clean[column].mean() + df_clean[column].std()/8 , y=axes.get_ylim()[1] * 0.90, s='Mean', fontsize=15, c='r')

  plt.axvline(df_clean[column].mean() + df_clean[column].std(), color='g', linestyle='dashed', linewidth=2)
  plt.text(x=df_clean[column].mean() + df_clean[column].std() + df_clean[column].std()/8 , y=axes.get_ylim()[1] * 0.75, s='+1σ', fontsize=15, c='g')

  plt.axvline(df_clean[column].mean() - df_clean[column].std(), color='g', linestyle='dashed', linewidth=2)
  plt.text(x=df_clean[column].mean() - df_clean[column].std() + df_clean[column].std()/8 , y=axes.get_ylim()[1] * 0.75, s='-1σ', fontsize=15, c='g')

plt.show()
# Does not like to show first time, please run twice if necessary

# %% [markdown]
# Magnitude has a mean of 6.9, a median of 6.8, and a standard deviation of 0.44. The small standard deviation shows that most recorded events stay close to the average. The distribution is positively skewed, demonstrating that higher-magnitude events 7.5 or greater are rare in comparison to the mean value. Because these right-tail extremes represent valid physical disasters rather than noise, we will keep them in our dataset.

# %% [markdown]
# Depth has a mean of 74.61 km, a median of 29.00 km, and a standard deviation of 130.02 km. The large standard deviation and high mean relative to the median, reflects an extreme positive skew. This highlights the wide physical scale of earthquake origins, ranging from frequent shallow events in the surface crust of 0-70km, to rarer, deep-mantle subduction events reaching depths of 300km or more.

# %% [markdown]
# Now for the mmi (Modified Mercalli Intensity) which is the reported local intensity .

# %%
stat_summ = df_clean["mmi"].agg(
    ["mean", "median", "min", "max", "std"]
)
print("mmi summary:")
print(stat_summ.round(2))
# Out:
# mmi summary:
# mean       6.03
# median     6.00
# min        1.00
# max       10.00
# std        1.43
# Name: mmi, dtype: float64

# %%
# Visualising distribution 
fig, axes = plt.subplots(figsize=(8,5))
plt.title("mmi distribution")
sns.histplot(
    data=df_clean,
    x="mmi",
    kde=True
  )

plt.axvline(df_clean["mmi"].mean(), color='r', linestyle='dashed', linewidth=2)
plt.text(x=df_clean["mmi"].mean() + df_clean["mmi"].std()/8 , y=axes.get_ylim()[1] * 0.90, s='Mean', fontsize=15, c='r')

plt.axvline(df_clean["mmi"].mean() + df_clean["mmi"].std(), color='g', linestyle='dashed', linewidth=2)
plt.text(x=df_clean["mmi"].mean() + df_clean["mmi"].std() + df_clean["mmi"].std()/8 , y=axes.get_ylim()[1] * 0.75, s='+1σ', fontsize=15, c='g')

plt.axvline(df_clean["mmi"].mean() - df_clean["mmi"].std(), color='g', linestyle='dashed', linewidth=2)
plt.text(x=df_clean["mmi"].mean() - df_clean["mmi"].std() + df_clean["mmi"].std()/8 , y=axes.get_ylim()[1] * 0.75, s='-1σ', fontsize=15, c='g')
plt.show()

# %% [markdown]
# Mmi has a mean of 6.03, a median of 6, and a standard deviation of 1.43. The close alignment between the mean and median indicates a near-normal, symmetric distribution with a modest standard deviation. This provides a balanced spread of events across the Mercalli scale (1-10), affriming it is ideal for establishing our high-severity threshold, mmi of 7 and greater.

# %% [markdown]
# Take look at how they distribute together.
#
# First just magnitude and depth.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_clean,
    x="depth",
    y="magnitude", 
)
plt.title("Magnitude vs Depth")
plt.xlabel("Depth (km)")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# Theres two distinct clusters. Which could mean that depth has some effect on magnitude, as there are more magnitude 7 and greater events happening at shallower depths of 200km or less than at 500km and below, with a mingling gap inbetween.
#
# Let's colour it by the MMI and see what that shows.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_clean,
    x="depth",
    y="magnitude",
    hue="mmi",
    palette="coolwarm",
    alpha=0.8
)
plt.title("Magnitude vs Depth by MMI")
plt.xlabel("Depth (km)")
plt.ylabel("Magnitude")
plt.show()

# %% [markdown]
# We see that the more severely rated events take place at the shallowest depths which is the expected. We're also seeing at which depths the magnitudes impact lessens. With the high magnitude, low mmi likely representing events happening in more remote or off-shore areas.

# %% [markdown]
# Now for the categorical columns.
#
# Let's see how magnitude types and tsunami generation are split.

# %%
# Storing columns in a list
categorical_columns = ["magType", "tsunami"]

# Loop through list to display summary
for column in categorical_columns:
    print(f"{column} reakdown: ")
    counts = df_clean[column].value_counts(dropna=False)
    percent = df_clean[column].value_counts(normalize=True, dropna=False) * 100
    print(pd.DataFrame({"Count": counts, "Percentage ": percent.round(2)}))
# Out:
# magType reakdown:
#          Count  Percentage
# magType
# mww        502         50.2
# mwc        332         33.2
# mwb        100         10.0
# mw          51          5.1
# Mi           5          0.5
# mb           4          0.4
# ms           3          0.3
# md           2          0.2
# ml           1          0.1
# tsunami reakdown:
#          Count  Percentage
# tsunami
# 0          675         67.5
# 1          325         32.5

# %%
# Visualise the spread
# ai formatted
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# 1. magType Distribution 
mag_order = df_clean["magType"].value_counts().index
sns.countplot(
    data=df_clean,
    y="magType",
    order=mag_order,
    ax=axes[0],
    palette="viridis"
)
axes[0].set_title("Distribution of Seismic Measurement Types (magType)")
axes[0].set_xlabel("Event Count")
axes[0].set_ylabel("Measurement Type")

# Add count annotations to bars
for p in axes[0].patches:
    width = p.get_width()
    axes[0].annotate(
        f"{int(width)} ({width/len(df_clean)*100:.1f}%)",
        (width + 5, p.get_y() + p.get_height() / 2),
        ha="left", va="center", fontsize=9
    )

# 2. Tsunami Class Balance (Count plot)
sns.countplot(
    data=df_clean,
    x="tsunami",
    ax=axes[1],
    palette=["#4C72B0", "#DD8452"]
)
axes[1].set_title("Tsunami Target Class Balance")
axes[1].set_xlabel("Tsunami Generated")
axes[1].set_ylabel("Event Count")
axes[1].set_xticklabels(["No Tsunami (67.5%)", "Tsunami (32.5%)"])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\NateM\AppData\Local\Temp\ipykernel_4560\3751501730.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\NateM\AppData\Local\Temp\ipykernel_4560\3751501730.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# C:\Users\NateM\AppData\Local\Temp\ipykernel_4560\3751501730.py:37: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(["No Tsunami (67.5%)", "Tsunami (32.5%)"])

# %% [markdown]
# The vast majority of the seismic events are recorded under moment magnitude variants, with mww and mwc accounting for 83.4% of the dataset. Conversely, the mi, mb, ms, md, and ml categories each contain five or fewer instances. Because cell counts below 5 violate Chi-Square test assumptions, these low-frequency types will be grouped into a single categorey "Other", prior to evaluating Hypothesis 2

# %% [markdown]
# The tsunami count shows a nearly 2:1 ratio (67.5% no tsunami to 32.5% tsunami generated, representing 325 positive events). This provides a robust and balanced target distribution for non-parametric statistical testing and classification modeling.

# %% [markdown]
# ---
